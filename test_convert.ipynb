# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
sns.set()

# %%
df = pd.DataFrame(np.random.randn(200, 5))

# %% [markdown]
# # Here is a header

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
df.plot(ax=ax1);
df.plot(ax=ax2);

# %% [markdown]
# aslkfdj;;;;;;;;;;;;;;;;;;;;;;;;;alkdfjalskdfjalksjfdalksfjdajalnvaksdvnalsvndasdvna;
#
# odvaoaodfoaljdfoajfoaljfolasjdfloasjfasljdfasljfdlasdfjalsdfjasldfjalosjfdolajfdloasdjfal
#
# sdkfjlasodjflasdjfalskdfjaslkdfjlasjfaslfjlaskdfjalskdfjlasdj

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
df.plot(ax=ax1);
df.plot(ax=ax2); 
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3.3), gridspec_kw={'width_ratios': [1, 2]})
df.plot(ax=ax1);
ax1.legend(bbox_to_anchor=(1,1))
df.plot(ax=ax2);
ax2.legend(bbox_to_anchor=(1,1))
ax2.set_ylabel('new label')
plt.tight_layout()

# %%
import plotly.express as px
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.update_layout(width=960)
fig.show() #renderer='svg', width=960)
# Out:
# <div>
#
#
#             <div id="58322cf9-60d4-45aa-95b7-de8e528f025b" class="plotly-graph-div" style="height:525px; width:960px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58322cf9-60d4-45aa-95b7-de8e528f025b")) {
#                     Plotly.newPlot(
#                         '58322cf9-60d4-45aa-95b7-de8e528f025b',
#                         [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0, 1, 2, 3, 4], "xaxis": "x", "y": [0, 1, 4, 9, 16], "yaxis": "y"}],
# ...
